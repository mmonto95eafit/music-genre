# %%
import pandas as pd
import numpy as np
import boto3
import io

# %%
# !conda install -c conda-forge librosa -y
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: /
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
# -
#   - conda-forge/noarch::seaborn-base==0.11.1=pyhd8ed1ab_1
#   - conda-forge/noarch::nbclassic==0.2.6=pyhd8ed1ab_0
#   - conda-forge/noarch::typing-extensions==3.7.4.3=0
#   - conda-forge/linux-64::pluggy==0.13.1=py36h5fab9bb_4
#   - conda-forge/linux-64::blaze==0.11.3=py36_0
#   - conda-forge/linux-64::matplotlib==3.3.4=py36h5fab9bb_0
#   - defaults/linux-64::_anaconda_depends==5.1.0=py36_2
#   - conda-forge/noarch::python-language-server==0.36.2=pyhd8ed1ab_0
#   - conda-forge/noarch::jupyterlab_server==2.3.0=pyhd8ed1ab_0
#   - conda-forge/noarch::pyls-black==0.4.6=pyh9f0ad1d_0
#   - conda-forge/linux-64::scikit-image==0.16.2=py36hb3f55d8_0
#   - conda-forge/noarch::path.py==12.5.0=0
#   - conda-forge/noarch::qdarkstyle==2.8.1=pyhd8ed1ab_2
#   - conda-forge/noarch::ipywidgets==7.6.3=pyhd3deb0d_0
#   - conda-forge/noarch::black==20.8b1=py_1
#   - conda-forge/linux-64::anyio==2.1.0=py36h5fab9bb_0
#   - conda-forge/linux-64::jupyter_server==1.4.1=py36h5fab9bb_0
#   - conda-forge/noarch::nbclient==0.5.2=pyhd8ed1ab_0
#   - conda-forge/linux-64::widgetsnbextension==3.5.1=py36h5fab9bb_4
#   - conda-forge/linux-64::bokeh==2.2.3=py36h5fab9bb_0
#   - conda-forge/linux-64::keyring==22.0.1=py36h5fab9bb_0
#   - conda-forge/linux-64::nbconvert==6.0.7=py36h5fab9bb_3
#   - conda-forge/noarch::numpydoc==1.1.0=py_1
#   - conda-forge/linux-64::spyder==4.2.0=py36h5fab9bb_0
#   - conda-forge/noarch::flake8==3.8.4=py_0
#   - conda-forge/noarch::pyls-spyder==0.3.2=pyhd8ed1ab_0
#   - conda-forge/noarch::nbformat==5.1.2=pyhd8ed1ab_1
#   - conda-forge/noarch::aioitertools==0.7.1=pyhd8ed1ab_0
#   - conda-forge/noarch::jupyterlab_launcher==0.13.1=py_2
#   - conda-forge/noarch::odo==0.5.1=py_1
#   - conda-forge/noarch::imageio==2.9.0=py_0
#   - conda-forge/noarch::helpdev==0.7.1=pyhd8ed1ab_0
#   - conda-forge/linux-64::path==15.1.2=py36h5fab9bb_0
#   - conda-forge/noarch::jsonschema==3.2.0=py_2
#   - conda-forge/linux-64::yarl==1.6.3=py36h8f6f2f9_1
#   - conda-forge/noarch::sphinx==3.5.1=pyhd8ed1ab_0
#   - conda-forge/noarch::seaborn==0.11.1=hd8ed1ab_1
#   - conda-forge/linux-64::jupyter==1.0.0=py36h5fab9bb_6
#   - conda-forge/linux-64::nb_conda==2.2.1=py36h5fab9bb_4
#   - conda-forge/noarch::dask==2021.2.0=pyhd8ed1ab_0
#   - conda-forge/linux-64::matplotlib-base==3.3.4=py36hd391965_0
#   - conda-forge/noarch::anaconda-client==1.7.2=py_0
#   - conda-forge/noarch::importlib_metadata==3.7.0=hd8ed1ab_0
#   - conda-forge/noarch::anaconda-project==0.9.1=pyhd8ed1ab_0
#   - conda-forge/linux-64::pytest==6.2.2=py36h5fab9bb_0
#   - conda-forge/linux-64::importlib-metadata==3.7.0=py36h5fab9bb_0
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.4
#   latest version: 4.10.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/ec2-user/anaconda3/envs/python3
#
#   added / updated specs:
#     - librosa
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     audioread-2.1.9            |   py36h5fab9bb_0          32 KB  conda-forge
#     charset-normalizer-2.0.9   |     pyhd8ed1ab_0          34 KB  conda-forge
#     dataclasses-0.8            |     pyh787bdff_2          22 KB  conda-forge
#     ffmpeg-4.3.2               |       hca11adc_0        92.0 MB  conda-forge
#     flask-cors-3.0.10          |     pyhd8ed1ab_0          15 KB  conda-forge
#     fsspec-2021.11.1           |     pyhd8ed1ab_0          91 KB  conda-forge
#     gnutls-3.6.13              |       h85f3911_1         2.0 MB  conda-forge
#     jupyter_console-5.2.0      |           py36_1          34 KB  conda-forge
#     jupyterlab-3.2.4           |     pyhd8ed1ab_0         6.1 MB  conda-forge
#     lame-3.100                 |    h7f98852_1001         496 KB  conda-forge
#     libflac-1.3.3              |       h9c3ff4c_1         486 KB  conda-forge
#     librosa-0.8.1              |     pyhd8ed1ab_0         147 KB  conda-forge
#     libsndfile-1.0.31          |       h9c3ff4c_1         602 KB  conda-forge
#     lxml-3.8.0                 |           py36_0         3.8 MB  conda-forge
#     nettle-3.6                 |       he412f7d_0         6.5 MB  conda-forge
#     notebook-6.3.0             |   py36h5fab9bb_0         6.3 MB  conda-forge
#     openh264-2.1.1             |       h780b84a_0         1.5 MB  conda-forge
#     pillow-7.2.0               |   py36h8328e55_2         679 KB  conda-forge
#     pooch-1.5.2                |     pyhd8ed1ab_0          45 KB  conda-forge
#     pylint-2.7.2               |   py36h5fab9bb_0         466 KB  conda-forge
#     pysoundfile-0.10.3.post1   |     pyhd3deb0d_0          23 KB  conda-forge
#     requests-2.26.0            |     pyhd8ed1ab_1          52 KB  conda-forge
#     resampy-0.2.2              |             py_0         332 KB  conda-forge
#     typing-extensions-4.0.1    |       hd8ed1ab_0           8 KB  conda-forge
#     typing_extensions-4.0.1    |     pyha770c72_0          26 KB  conda-forge
#     x264-1!161.3030            |       h7f98852_1         2.5 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       124.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   astroid            conda-forge/linux-64::astroid-2.5.8-py36h5fab9bb_0
#   audioread          conda-forge/linux-64::audioread-2.1.9-py36h5fab9bb_0
#   charset-normalizer conda-forge/noarch::charset-normalizer-2.0.9-pyhd8ed1ab_0
#   colorama           conda-forge/noarch::colorama-0.4.4-pyh9f0ad1d_0
#   dataclasses        conda-forge/noarch::dataclasses-0.8-pyh787bdff_2
#   docutils           conda-forge/linux-64::docutils-0.16-py36h5fab9bb_3
#   ffmpeg             conda-forge/linux-64::ffmpeg-4.3.2-hca11adc_0
#   flask-cors         conda-forge/noarch::flask-cors-3.0.10-pyhd8ed1ab_0
#   fsspec             conda-forge/noarch::fsspec-2021.11.1-pyhd8ed1ab_0
#   gnutls             conda-forge/linux-64::gnutls-3.6.13-h85f3911_1
#   jupyter_console    conda-forge/linux-64::jupyter_console-5.2.0-py36_1
#   jupyterlab         conda-forge/noarch::jupyterlab-3.2.4-pyhd8ed1ab_0
#   lame               conda-forge/linux-64::lame-3.100-h7f98852_1001
#   libflac            conda-forge/linux-64::libflac-1.3.3-h9c3ff4c_1
#   libogg             conda-forge/linux-64::libogg-1.3.4-h7f98852_1
#   libopus            conda-forge/linux-64::libopus-1.3.1-h7f98852_1
#   librosa            conda-forge/noarch::librosa-0.8.1-pyhd8ed1ab_0
#   libsndfile         conda-forge/linux-64::libsndfile-1.0.31-h9c3ff4c_1
#   libvorbis          conda-forge/linux-64::libvorbis-1.3.7-h9c3ff4c_0
#   lxml               conda-forge/linux-64::lxml-3.8.0-py36_0
#   nettle             conda-forge/linux-64::nettle-3.6-he412f7d_0
#   notebook           conda-forge/linux-64::notebook-6.3.0-py36h5fab9bb_0
#   openh264           conda-forge/linux-64::openh264-2.1.1-h780b84a_0
#   pillow             conda-forge/linux-64::pillow-7.2.0-py36h8328e55_2
#   pip                conda-forge/noarch::pip-21.3.1-pyhd8ed1ab_0
#   pooch              conda-forge/noarch::pooch-1.5.2-pyhd8ed1ab_0
#   pylint             conda-forge/linux-64::pylint-2.7.2-py36h5fab9bb_0
#   pysoundfile        conda-forge/noarch::pysoundfile-0.10.3.post1-pyhd3deb0d_0
#   requests           conda-forge/noarch::requests-2.26.0-pyhd8ed1ab_1
#   resampy            conda-forge/noarch::resampy-0.2.2-py_0
#   typing_extensions  conda-forge/noarch::typing_extensions-4.0.1-pyha770c72_0
#   urllib3            conda-forge/noarch::urllib3-1.26.7-pyhd8ed1ab_0
#   x264               conda-forge/linux-64::x264-1!161.3030-h7f98852_1
#
# The following packages will be UPDATED:
#
#   ca-certificates                      2021.5.30-ha878542_0 --> 2021.10.8-ha878542_0
#   typing-extensions                               3.7.4.3-0 --> 4.0.1-hd8ed1ab_0
#
#
#
# Downloading and Extracting Packages
# requests-2.26.0      | 52 KB     | ##################################### | 100%
# notebook-6.3.0       | 6.3 MB    | ##################################### | 100%
# jupyterlab-3.2.4     | 6.1 MB    | ##################################### | 100%
# ffmpeg-4.3.2         | 92.0 MB   | ##################################### | 100%
# openh264-2.1.1       | 1.5 MB    | ##################################### | 100%
# flask-cors-3.0.10    | 15 KB     | ##################################### | 100%
# libsndfile-1.0.31    | 602 KB    | ##################################### | 100%
# audioread-2.1.9      | 32 KB     | ##################################### | 100%
# gnutls-3.6.13        | 2.0 MB    | ##################################### | 100%
# typing-extensions-4. | 8 KB      | ##################################### | 100%
# librosa-0.8.1        | 147 KB    | ##################################### | 100%
# dataclasses-0.8      | 22 KB     | ##################################### | 100%
# libflac-1.3.3        | 486 KB    | ##################################### | 100%
# charset-normalizer-2 | 34 KB     | ##################################### | 100%
# nettle-3.6           | 6.5 MB    | ##################################### | 100%
# pillow-7.2.0         | 679 KB    | ##################################### | 100%
# pysoundfile-0.10.3.p | 23 KB     | ##################################### | 100%
# fsspec-2021.11.1     | 91 KB     | ##################################### | 100%
# lame-3.100           | 496 KB    | ##################################### | 100%
# resampy-0.2.2        | 332 KB    | ##################################### | 100%
# typing_extensions-4. | 26 KB     | ##################################### | 100%
# pooch-1.5.2          | 45 KB     | ##################################### | 100%
# lxml-3.8.0           | 3.8 MB    | ##################################### | 100%
# pylint-2.7.2         | 466 KB    | ##################################### | 100%
# jupyter_console-5.2. | 34 KB     | ##################################### | 100%
# x264-1!161.3030      | 2.5 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
import librosa

# %%
data_dir = 's3://musicgenredatalake/'

genres = ['blues', 'classical', 'country', 'disco',
          'hiphop', 'jazz', 'metal', 'pop', 'reggae', 'rock']
window_size = 3

# %%
columns = ['filename', 'length', 'chroma_stft_mean', 'chroma_stft_var', 'rms_mean',
           'rms_var', 'spectral_centroid_mean', 'spectral_centroid_var',
           'spectral_bandwidth_mean', 'spectral_bandwidth_var', 'rolloff_mean',
           'rolloff_var', 'zero_crossing_rate_mean', 'zero_crossing_rate_var',
           'harmony_mean', 'harmony_var', 'perceptr_mean', 'perceptr_var', 'tempo',
           'mfcc1_mean', 'mfcc1_var', 'mfcc2_mean', 'mfcc2_var', 'mfcc3_mean',
           'mfcc3_var', 'mfcc4_mean', 'mfcc4_var', 'mfcc5_mean', 'mfcc5_var',
           'mfcc6_mean', 'mfcc6_var', 'mfcc7_mean', 'mfcc7_var', 'mfcc8_mean',
           'mfcc8_var', 'mfcc9_mean', 'mfcc9_var', 'mfcc10_mean', 'mfcc10_var',
           'mfcc11_mean', 'mfcc11_var', 'mfcc12_mean', 'mfcc12_var', 'mfcc13_mean',
           'mfcc13_var', 'mfcc14_mean', 'mfcc14_var', 'mfcc15_mean', 'mfcc15_var',
           'mfcc16_mean', 'mfcc16_var', 'mfcc17_mean', 'mfcc17_var', 'mfcc18_mean',
           'mfcc18_var', 'mfcc19_mean', 'mfcc19_var', 'mfcc20_mean', 'mfcc20_var', 'label']

# %%
def extract_features(window):
    ''' Pendiente documentar '''

    chromogram = librosa.feature.chroma_stft(window)
    rms = librosa.feature.rms(window)
    centroid = librosa.feature.spectral_centroid(window)
    bandwidth = librosa.feature.spectral_bandwidth(window)
    roll_off = librosa.feature.spectral_rolloff(window)
    zero_crossing_rate = librosa.feature.zero_crossing_rate(window)
    harmony, perceptual = librosa.effects.hpss(window)
    tempo, _ = librosa.beat.beat_track(window)
    mfcc = librosa.feature.mfcc(window)

    mfcc_values = []
    for mean, var in zip(mfcc.mean(axis=1), np.var(mfcc, axis=1)):
        mfcc_values.append(mean)
        mfcc_values.append(var)

    return [
        chromogram.mean(),
        np.var(chromogram),
        rms.mean(),
        np.var(rms),
        centroid.mean(),
        np.var(centroid),
        bandwidth.mean(),
        np.var(bandwidth),
        roll_off.mean(),
        np.var(roll_off),
        zero_crossing_rate.mean(),
        np.var(zero_crossing_rate),
        harmony.mean(),
        np.var(harmony),
        perceptual.mean(),
        np.var(perceptual),
        tempo,
        *mfcc_values
    ]

# %%
bucket = 'musicgenredatalake'
client = boto3.client('s3')
paginator = client.get_paginator('list_objects_v2')

# %%
features = []
for genre in genres:
    page_iterator = paginator.paginate(Bucket=bucket,Prefix='raw/songs/'+f'{genre}'+'/')    
    for files in page_iterator:
        for file_content in files['Contents']:            
            obj = client.get_object(Bucket=bucket, Key=file_content['Key'])
            data = io.BytesIO(obj['Body'].read())                 
            try:
                #signal, sample_rate = librosa.load(f'{data_dir}/file_content['Key']')
                signal, sample_rate = librosa.load(data)
                
                # Get rid of silence at the begining and end
                signal, _ = librosa.effects.trim(signal)
                n_points = window_size * sample_rate
                for i in range(int(len(signal) / n_points)):
                    print(genre, file_content['Key'], i, end='\r')
                    window = signal[i * n_points:(i + 1) * n_points]
                    if len(window):
                        values = extract_features(window)
                        values = [file_content['Key'].replace('.wav', f'.{i}.wav'), len(
                            window), *values, genre]
                        features.append(values)
            except Exception as ex:
                print(ex)
                print(file_content['Key'])
# Out:
# Error opening <_io.BytesIO object at 0x7f19f987f990>: Format not recognised.
# raw/songs/jazz/jazz.00054.wav
# 3000 secondsgs/rock/rock.00099.wav 9.wav 9

# %%
df = pd.DataFrame(features)
df.columns = columns

# %%
df
# Out:
#                                filename  length  chroma_stft_mean  \
# 0     raw/songs/blues/blues.00000.0.wav   66150          0.335434
# 1     raw/songs/blues/blues.00000.1.wav   66150          0.343020
# 2     raw/songs/blues/blues.00000.2.wav   66150          0.346838
# 3     raw/songs/blues/blues.00000.3.wav   66150          0.363671
# 4     raw/songs/blues/blues.00000.4.wav   66150          0.335927
# ...                                 ...     ...               ...
# 9975    raw/songs/rock/rock.00099.5.wav   66150          0.349242
# 9976    raw/songs/rock/rock.00099.6.wav   66150          0.372667
# 9977    raw/songs/rock/rock.00099.7.wav   66150          0.347207
# 9978    raw/songs/rock/rock.00099.8.wav   66150          0.387354
# 9979    raw/songs/rock/rock.00099.9.wav   66150          0.369244
#
#       chroma_stft_var  rms_mean   rms_var  spectral_centroid_mean  \
# 0            0.091088  0.130405  0.003521             1773.285877
# 1            0.086142  0.112699  0.001450             1816.195860
# 2            0.092210  0.132002  0.004620             1788.642783
# 3            0.086856  0.132562  0.002447             1654.902168
# 4            0.088291  0.143289  0.001701             1630.737016
# ...               ...       ...       ...                     ...
# 9975         0.080523  0.050019  0.000097             1499.033450
# 9976         0.082638  0.057897  0.000088             1847.993568
# 9977         0.088840  0.052402  0.000701             1346.166433
# 9978         0.084762  0.066430  0.000320             2084.876439
# 9979         0.086697  0.050524  0.000067             1634.338776
#
#       spectral_centroid_var  spectral_bandwidth_mean  spectral_bandwidth_var  \
# 0             168244.728456              1972.723622           117298.851602
# 1              90703.325338              2009.201574            65548.531299
# 2             111322.536900              2085.045996            74755.260774
# 3             112316.264418              1959.202709            83672.222471
# 4              79648.228139              1948.459295            60221.594973
# ...                     ...                      ...                     ...
# 9975          164296.529369              1718.741487            85910.800675
# 9976          281007.291156              1906.381942            99815.431761
# 9977          662977.658874              1562.051939           139002.058162
# 9978          203148.324687              2019.066228            22200.073698
# 9979          411437.299295              1867.300772           119680.970130
#
#       ...  mfcc16_var  mfcc17_mean  mfcc17_var  mfcc18_mean  mfcc18_var  \
# 0     ...   39.725567    -3.241225   36.486431     0.721986   38.096764
# 1     ...   65.312981    -6.100084   40.738815     0.219240   50.587795
# 2     ...   67.582199    -1.801321   28.132212     2.308316   48.102489
# 3     ...   47.059677    -3.859234   27.984928     1.255384   35.093281
# 4     ...   30.307617     0.629568   44.883640     1.709780   51.706696
# ...   ...         ...          ...         ...          ...         ...
# 9975  ...   42.411774    -9.072774   38.522137    -4.239303   31.064833
# 9976  ...   32.480297   -12.389524   65.873482    -3.085007   54.283779
# 9977  ...   78.050781    -2.524270   21.777952     4.799636   25.962271
# 9978  ...   28.323929    -5.370701   17.280422     6.469846   21.370140
# 9979  ...   38.766556   -11.629149   58.856182    -0.163734   55.716457
#
#       mfcc19_mean  mfcc19_var  mfcc20_mean  mfcc20_var  label
# 0       -5.043307   33.608330    -0.237658   43.827778  blues
# 1       -2.875456   96.975441     5.800725   60.006115  blues
# 2       -1.931482   53.116806     2.522431   33.136238  blues
# 3       -3.619866   51.420628     3.639336   31.930040  blues
# 4       -3.402105   26.686306     0.546948   29.212286  blues
# ...           ...         ...          ...         ...    ...
# 9975    -5.625191   48.812855     1.794132   38.993576   rock
# 9976   -11.963290   63.390671     0.404298   18.759731   rock
# 9977     1.797535   48.307678    -0.320112   41.750011   rock
# 9978     2.359090   24.827066     0.688447   12.747363   rock
# 9979    -6.901929   39.505505    -3.406077   31.736723   rock
#
# [9980 rows x 60 columns]

# %%
def mahalanobis(x=None, data=None, cov=None):

    x_mu = x - np.mean(data)
    #if not cov:
        #cov = np.cov(x.T)
    inv_cov = np.linalg.inv(cov)
    mahalanobis_distances = np.diag(np.dot((x_mu @ inv_cov), x_mu.T))
   
    return mahalanobis_distances

# %%
from sklearn.preprocessing import MinMaxScaler
df['label'] = df['label'].astype('category')
df['length'] = pd.to_numeric(df['length'])
df_x = df.drop(['filename', 'label', 'length'], axis=1)
x = np.array(df_x)
y = df['label'].cat.codes.values
scaler = MinMaxScaler()
x_norm = scaler.fit_transform(x)
data = df.iloc[:, 2:-1]
data_norm = scaler.fit_transform(data)
cov_h_norm = np.cov(x_norm.T)
cov_i_norm = cov_h_norm + 10 * np.eye(57, 57)
mahalanobis_dis_i_norm = mahalanobis(x=x_norm, data=data_norm, cov=cov_i_norm)
p25 = np.percentile(mahalanobis_dis_i_norm, 25)
p75 = np.percentile(mahalanobis_dis_i_norm, 75)
threshold = p75 + 3 * (p75 - p25)
x_fn = x_norm[mahalanobis_dis_i_norm < threshold]
y_fn = y[mahalanobis_dis_i_norm < threshold]
cols = df_x.columns
df_X_fn = pd.DataFrame(x_fn)

# %%
cols = ['chroma_stft_mean', 'chroma_stft_var', 'rms_mean',
           'rms_var', 'spectral_centroid_mean', 'spectral_centroid_var',
           'spectral_bandwidth_mean', 'spectral_bandwidth_var', 'rolloff_mean',
           'rolloff_var', 'zero_crossing_rate_mean', 'zero_crossing_rate_var',
           'harmony_mean', 'harmony_var', 'perceptr_mean', 'perceptr_var', 'tempo',
           'mfcc1_mean', 'mfcc1_var', 'mfcc2_mean', 'mfcc2_var', 'mfcc3_mean',
           'mfcc3_var', 'mfcc4_mean', 'mfcc4_var', 'mfcc5_mean', 'mfcc5_var',
           'mfcc6_mean', 'mfcc6_var', 'mfcc7_mean', 'mfcc7_var', 'mfcc8_mean',
           'mfcc8_var', 'mfcc9_mean', 'mfcc9_var', 'mfcc10_mean', 'mfcc10_var',
           'mfcc11_mean', 'mfcc11_var', 'mfcc12_mean', 'mfcc12_var', 'mfcc13_mean',
           'mfcc13_var', 'mfcc14_mean', 'mfcc14_var', 'mfcc15_mean', 'mfcc15_var',
           'mfcc16_mean', 'mfcc16_var', 'mfcc17_mean', 'mfcc17_var', 'mfcc18_mean',
           'mfcc18_var', 'mfcc19_mean', 'mfcc19_var', 'mfcc20_mean', 'mfcc20_var', 'label']

# %%
df_X_fn['57']=y_fn
df_fn=df_X_fn
df_fn.columns=cols

# %%
df_fn.to_csv('s3://musicgenredatalake/trusted/dataset/features_3_sec.csv', index=False)
