# %%
import numpy as np
import pandas as pd

# %%
data_path = '../data/features_3_sec.csv'

# %%
df = pd.read_csv(data_path)
df['label'] = df['label'].astype('category')

# %%
df
# Out:
#                filename  length  chroma_stft_mean  chroma_stft_var  rms_mean  \
# 0     blues.00000.0.wav   66149          0.335406         0.091048  0.130405
# 1     blues.00000.1.wav   66149          0.343065         0.086147  0.112699
# 2     blues.00000.2.wav   66149          0.346815         0.092243  0.132003
# 3     blues.00000.3.wav   66149          0.363639         0.086856  0.132565
# 4     blues.00000.4.wav   66149          0.335579         0.088129  0.143289
# ...                 ...     ...               ...              ...       ...
# 9985   rock.00099.5.wav   66149          0.349126         0.080515  0.050019
# 9986   rock.00099.6.wav   66149          0.372564         0.082626  0.057897
# 9987   rock.00099.7.wav   66149          0.347481         0.089019  0.052403
# 9988   rock.00099.8.wav   66149          0.387527         0.084815  0.066430
# 9989   rock.00099.9.wav   66149          0.369293         0.086759  0.050524
#
#        rms_var  spectral_centroid_mean  spectral_centroid_var  \
# 0     0.003521             1773.065032          167541.630869
# 1     0.001450             1816.693777           90525.690866
# 2     0.004620             1788.539719          111407.437613
# 3     0.002448             1655.289045          111952.284517
# 4     0.001701             1630.656199           79667.267654
# ...        ...                     ...                    ...
# 9985  0.000097             1499.083005          164266.886443
# 9986  0.000088             1847.965128          281054.935973
# 9987  0.000701             1346.157659          662956.246325
# 9988  0.000320             2084.515327          203891.039161
# 9989  0.000067             1634.330126          411429.169769
#
#       spectral_bandwidth_mean  spectral_bandwidth_var  ...  mfcc16_var  \
# 0                 1972.744388           117335.771563  ...   39.687145
# 1                 2010.051501            65671.875673  ...   64.748276
# 2                 2084.565132            75124.921716  ...   67.336563
# 3                 1960.039988            82913.639269  ...   47.739452
# 4                 1948.503884            60204.020268  ...   30.336359
# ...                       ...                     ...  ...         ...
# 9985              1718.707215            85931.574523  ...   42.485981
# 9986              1906.468492            99727.037054  ...   32.415203
# 9987              1561.859087           138762.841945  ...   78.228149
# 9988              2018.366254            22860.992562  ...   28.323744
# 9989              1867.422378           119722.211518  ...   38.801735
#
#       mfcc17_mean  mfcc17_var  mfcc18_mean  mfcc18_var  mfcc19_mean  \
# 0       -3.241280   36.488243     0.722209   38.099152    -5.050335
# 1       -6.055294   40.677654     0.159015   51.264091    -2.837699
# 2       -1.768610   28.348579     2.378768   45.717648    -1.938424
# 3       -3.841155   28.337118     1.218588   34.770935    -3.580352
# 4        0.664582   45.880913     1.689446   51.363583    -3.392489
# ...           ...         ...          ...         ...          ...
# 9985    -9.094270   38.326839    -4.246976   31.049839    -5.625813
# 9986   -12.375726   66.418587    -3.081278   54.414265   -11.960546
# 9987    -2.524483   21.778994     4.809936   25.980829     1.775686
# 9988    -5.363541   17.209942     6.462601   21.442928     2.354765
# 9989   -11.598399   58.983097    -0.178517   55.761299    -6.903252
#
#       mfcc19_var  mfcc20_mean  mfcc20_var  label
# 0      33.618073    -0.243027   43.771767  blues
# 1      97.030830     5.784063   59.943081  blues
# 2      53.050835     2.517375   33.105122  blues
# 3      50.836224     3.630866   32.023678  blues
# 4      26.738789     0.536961   29.146694  blues
# ...          ...          ...         ...    ...
# 9985   48.804092     1.818823   38.966969   rock
# 9986   63.452255     0.428857   18.697033   rock
# 9987   48.582378    -0.299545   41.586990   rock
# 9988   24.843613     0.675824   12.787750   rock
# 9989   39.485901    -3.412534   31.727489   rock
#
# [9990 rows x 60 columns]

# %% [markdown]
# ### descriptivos básicos (Cuenta, media, desviación estandar, minimos, máximos, percentiles)

# %%
df.describe()
# Out:
#         length  chroma_stft_mean  chroma_stft_var     rms_mean       rms_var  \
# count   9990.0       9990.000000      9990.000000  9990.000000  9.990000e+03
# mean   66149.0          0.379534         0.084876     0.130859  2.676388e-03
# std        0.0          0.090466         0.009637     0.068545  3.585628e-03
# min    66149.0          0.107108         0.015345     0.000953  4.379535e-08
# 25%    66149.0          0.315698         0.079833     0.083782  6.145900e-04
# 50%    66149.0          0.384741         0.085108     0.121253  1.491318e-03
# 75%    66149.0          0.442443         0.091092     0.176328  3.130862e-03
# max    66149.0          0.749481         0.120964     0.442567  3.261522e-02
#
#        spectral_centroid_mean  spectral_centroid_var  spectral_bandwidth_mean  \
# count             9990.000000           9.990000e+03              9990.000000
# mean              2199.219431           4.166727e+05              2241.385959
# std                751.860611           4.349644e+05               543.854449
# min                472.741636           8.118813e+02               499.162910
# 25%               1630.680158           1.231961e+05              1887.455790
# 50%               2208.628236           2.650692e+05              2230.575595
# 75%               2712.581884           5.624152e+05              2588.340505
# max               5432.534406           4.794119e+06              3708.147554
#
#        spectral_bandwidth_var  rolloff_mean  ...  mfcc16_mean   mfcc16_var  \
# count            9.990000e+03   9990.000000  ...  9990.000000  9990.000000
# mean             1.182711e+05   4566.076592  ...     1.448240    49.988755
# std              1.013505e+05   1642.065335  ...     5.735149    34.442816
# min              1.183520e+03    658.336276  ...   -26.850016     1.325786
# 25%              4.876553e+04   3378.311110  ...    -2.227478    29.584894
# 50%              8.996072e+04   4631.377892  ...     1.461623    41.702393
# 75%              1.585674e+05   5591.634521  ...     5.149752    59.274619
# max              1.235143e+06   9487.446477  ...    39.144405   683.932556
#
#        mfcc17_mean   mfcc17_var  mfcc18_mean   mfcc18_var  mfcc19_mean  \
# count  9990.000000  9990.000000  9990.000000  9990.000000  9990.000000
# mean     -4.198706    51.962753     0.739943    52.488851    -2.497306
# std       5.677379    36.400669     5.181313    38.177120     5.111799
# min     -27.809795     1.624544   -20.733809     3.437439   -27.448456
# 25%      -7.951722    29.863448    -2.516638    29.636197    -5.734123
# 50%      -4.443021    42.393583     0.733772    41.831377    -2.702366
# 75%      -0.726945    61.676964     3.888734    62.033906     0.514246
# max      34.048843   529.363342    36.970322   629.729797    31.365425
#
#         mfcc19_var  mfcc20_mean   mfcc20_var
# count  9990.000000  9990.000000  9990.000000
# mean     54.973829    -0.917584    57.322614
# std      41.585677     5.253243    46.444212
# min       3.065302   -35.640659     0.282131
# 25%      30.496412    -4.004475    30.011365
# 50%      43.435253    -1.030939    44.332155
# 75%      65.328602     2.216603    68.210421
# max    1143.230591    34.212101   910.473206
#
# [8 rows x 58 columns]

# %%
df_x = df.drop(['filename','label'],axis=1)
df_x
# Out:
#       length  chroma_stft_mean  chroma_stft_var  rms_mean   rms_var  \
# 0      66149          0.335406         0.091048  0.130405  0.003521
# 1      66149          0.343065         0.086147  0.112699  0.001450
# 2      66149          0.346815         0.092243  0.132003  0.004620
# 3      66149          0.363639         0.086856  0.132565  0.002448
# 4      66149          0.335579         0.088129  0.143289  0.001701
# ...      ...               ...              ...       ...       ...
# 9985   66149          0.349126         0.080515  0.050019  0.000097
# 9986   66149          0.372564         0.082626  0.057897  0.000088
# 9987   66149          0.347481         0.089019  0.052403  0.000701
# 9988   66149          0.387527         0.084815  0.066430  0.000320
# 9989   66149          0.369293         0.086759  0.050524  0.000067
#
#       spectral_centroid_mean  spectral_centroid_var  spectral_bandwidth_mean  \
# 0                1773.065032          167541.630869              1972.744388
# 1                1816.693777           90525.690866              2010.051501
# 2                1788.539719          111407.437613              2084.565132
# 3                1655.289045          111952.284517              1960.039988
# 4                1630.656199           79667.267654              1948.503884
# ...                      ...                    ...                      ...
# 9985             1499.083005          164266.886443              1718.707215
# 9986             1847.965128          281054.935973              1906.468492
# 9987             1346.157659          662956.246325              1561.859087
# 9988             2084.515327          203891.039161              2018.366254
# 9989             1634.330126          411429.169769              1867.422378
#
#       spectral_bandwidth_var  rolloff_mean  ...  mfcc16_mean  mfcc16_var  \
# 0              117335.771563   3714.560359  ...    -2.853603   39.687145
# 1               65671.875673   3869.682242  ...     4.074709   64.748276
# 2               75124.921716   3997.639160  ...     4.806280   67.336563
# 3               82913.639269   3568.300218  ...    -1.359111   47.739452
# 4               60204.020268   3469.992864  ...     2.092937   30.336359
# ...                      ...           ...  ...          ...         ...
# 9985            85931.574523   3015.559458  ...     5.773784   42.485981
# 9986            99727.037054   3746.694524  ...     2.074155   32.415203
# 9987           138762.841945   2442.362154  ...    -1.005473   78.228149
# 9988            22860.992562   4313.266226  ...     4.123402   28.323744
# 9989           119722.211518   3462.042142  ...     1.342274   38.801735
#
#       mfcc17_mean  mfcc17_var  mfcc18_mean  mfcc18_var  mfcc19_mean  \
# 0       -3.241280   36.488243     0.722209   38.099152    -5.050335
# 1       -6.055294   40.677654     0.159015   51.264091    -2.837699
# 2       -1.768610   28.348579     2.378768   45.717648    -1.938424
# 3       -3.841155   28.337118     1.218588   34.770935    -3.580352
# 4        0.664582   45.880913     1.689446   51.363583    -3.392489
# ...           ...         ...          ...         ...          ...
# 9985    -9.094270   38.326839    -4.246976   31.049839    -5.625813
# 9986   -12.375726   66.418587    -3.081278   54.414265   -11.960546
# 9987    -2.524483   21.778994     4.809936   25.980829     1.775686
# 9988    -5.363541   17.209942     6.462601   21.442928     2.354765
# 9989   -11.598399   58.983097    -0.178517   55.761299    -6.903252
#
#       mfcc19_var  mfcc20_mean  mfcc20_var
# 0      33.618073    -0.243027   43.771767
# 1      97.030830     5.784063   59.943081
# 2      53.050835     2.517375   33.105122
# 3      50.836224     3.630866   32.023678
# 4      26.738789     0.536961   29.146694
# ...          ...          ...         ...
# 9985   48.804092     1.818823   38.966969
# 9986   63.452255     0.428857   18.697033
# 9987   48.582378    -0.299545   41.586990
# 9988   24.843613     0.675824   12.787750
# 9989   39.485901    -3.412534   31.727489
#
# [9990 rows x 58 columns]

# %% [markdown]
# ### Asimetría

# %%
import scipy.stats as sp

asimetria = {}

for column in df_x:
    
    asimetria[str(column)] = sp.skew(df[column])


asimetria
# Out:
# {'length': 0.0,
#  'chroma_stft_mean': -0.017921626977713632,
#  'chroma_stft_var': -0.7735637514677222,
#  'rms_mean': 0.4990537676707006,
#  'rms_var': 3.0708784253898784,
#  'spectral_centroid_mean': 0.2710432335346781,
#  'spectral_centroid_var': 2.224664865044577,
#  'spectral_bandwidth_mean': 0.05791440548166044,
#  'spectral_bandwidth_var': 2.2634092771217422,
#  'rolloff_mean': 0.1009979702701323,
#  'rolloff_var': 1.7148200272816962,
#  'zero_crossing_rate_mean': 0.6533591554883531,
#  'zero_crossing_rate_var': 3.8687209811656476,
#  'harmony_mean': -6.183408189450232,
#  'harmony_var': 2.033958693405061,
#  'perceptr_mean': -1.469387004132523,
#  'perceptr_var': 2.3096028532083928,
#  'tempo': 0.6785048495972392,
#  'mfcc1_mean': -1.1134232110157132,
#  'mfcc1_var': 3.6819111143899237,
#  'mfcc2_mean': 0.4041113430411442,
#  'mfcc2_var': 2.104082208474382,
#  'mfcc3_mean': 0.2537045328127596,
#  'mfcc3_var': 2.364564145726158,
#  'mfcc4_mean': -0.05462471807578633,
#  'mfcc4_var': 2.0451504881293285,
#  'mfcc5_mean': -0.09556904779373071,
#  'mfcc5_var': 2.4101770199951806,
#  'mfcc6_mean': -0.162023375757739,
#  'mfcc6_var': 1.9080382514958172,
#  'mfcc7_mean': 0.04193673256596422,
#  'mfcc7_var': 1.7481281740178631,
#  'mfcc8_mean': -0.10658203932076621,
#  'mfcc8_var': 1.8340971777498267,
#  'mfcc9_mean': 0.03949681624841879,
#  'mfcc9_var': 1.693444176998144,
#  'mfcc10_mean': -0.07883207201335803,
#  'mfcc10_var': 2.0326480142129726,
#  'mfcc11_mean': -0.06344397865552197,
#  'mfcc11_var': 2.9787942355670234,
#  'mfcc12_mean': -0.044522581582615586,
#  'mfcc12_var': 3.555117991121833,
#  'mfcc13_mean': -0.0005097778145549512,
#  'mfcc13_var': 3.077222934688896,
#  'mfcc14_mean': -0.026588197842939174,
#  'mfcc14_var': 5.441359870224785,
#  'mfcc15_mean': 0.15368505936530277,
#  'mfcc15_var': 4.289661811487928,
#  'mfcc16_mean': -0.0017473398243391094,
#  'mfcc16_var': 4.274242807346197,
#  'mfcc17_mean': 0.4508735226515373,
#  'mfcc17_var': 3.133753798279348,
#  'mfcc18_mean': 0.2641783298513575,
#  'mfcc18_var': 3.254588018471589,
#  'mfcc19_mean': 0.38951942348139756,
#  'mfcc19_var': 4.801632519774475,
#  'mfcc20_mean': 0.06077438335899313,
#  'mfcc20_var': 4.008470589998215}

# %% [markdown]
# ### Kurtosis

# %%
kurtosis = {}

for column in df_x:
    
    kurtosis[str(column)] = sp.kurtosis(df[column])


kurtosis
# Out:
# {'length': -3.0,
#  'chroma_stft_mean': -0.19250306009992935,
#  'chroma_stft_var': 2.863344331120163,
#  'rms_mean': 0.059102163263382135,
#  'rms_var': 12.339666540693354,
#  'spectral_centroid_mean': -0.13655926666980545,
#  'spectral_centroid_var': 7.376985857013429,
#  'spectral_bandwidth_mean': -0.343496147223489,
#  'spectral_bandwidth_var': 9.532343316415293,
#  'rolloff_mean': -0.3634160617614435,
#  'rolloff_var': 3.781258444387814,
#  'zero_crossing_rate_mean': 0.5032873209353146,
#  'zero_crossing_rate_var': 25.643143348959217,
#  'harmony_mean': 92.72551062525233,
#  'harmony_var': 5.842533171829958,
#  'perceptr_mean': 8.114079593579717,
#  'perceptr_var': 7.6061013042438805,
#  'tempo': 0.72820057147573,
#  'mfcc1_mean': 1.4144174529898699,
#  'mfcc1_var': 31.322245268441584,
#  'mfcc2_mean': 0.17813905138013153,
#  'mfcc2_var': 7.503676905980216,
#  'mfcc3_mean': -0.035307958708377996,
#  'mfcc3_var': 10.59289621757047,
#  'mfcc4_mean': -0.25567908327007105,
#  'mfcc4_var': 10.904968891272182,
#  'mfcc5_mean': -0.2681948136114549,
#  'mfcc5_var': 13.29744680304303,
#  'mfcc6_mean': -0.5241732438420659,
#  'mfcc6_var': 6.199238486924008,
#  'mfcc7_mean': -0.6345951191230546,
#  'mfcc7_var': 4.900913477188317,
#  'mfcc8_mean': -0.2688284941055863,
#  'mfcc8_var': 6.298432575351084,
#  'mfcc9_mean': -0.4504117591121428,
#  'mfcc9_var': 4.389854094945947,
#  'mfcc10_mean': -0.29726429126465703,
#  'mfcc10_var': 7.914185502730419,
#  'mfcc11_mean': 0.1284896188871807,
#  'mfcc11_var': 20.120758020482665,
#  'mfcc12_mean': -0.24680889784390692,
#  'mfcc12_var': 25.930878377946726,
#  'mfcc13_mean': 0.0916993743133192,
#  'mfcc13_var': 19.795848759724855,
#  'mfcc14_mean': 0.39052382150186116,
#  'mfcc14_var': 68.52858071395444,
#  'mfcc15_mean': 0.44796079987052373,
#  'mfcc15_var': 34.381350078574755,
#  'mfcc16_mean': 1.266436251653289,
#  'mfcc16_var': 40.38618005294399,
#  'mfcc17_mean': 1.3656540742714816,
#  'mfcc17_var': 17.37276482873749,
#  'mfcc18_mean': 1.549980185969046,
#  'mfcc18_var': 19.79751015197733,
#  'mfcc19_mean': 1.7632364253261157,
#  'mfcc19_var': 66.62392139514967,
#  'mfcc20_mean': 2.2285397951198354,
#  'mfcc20_var': 34.37206201368613}

# %% [markdown]
# ### Matriz de Covarianza

# %%
X = np.array(df_x)
X
# Out:
# array([[ 6.61490000e+04,  3.35406363e-01,  9.10482928e-02, ...,
#          3.36180725e+01, -2.43026793e-01,  4.37717667e+01],
#        [ 6.61490000e+04,  3.43065351e-01,  8.61465260e-02, ...,
#          9.70308304e+01,  5.78406334e+00,  5.99430809e+01],
#        [ 6.61490000e+04,  3.46814752e-01,  9.22428891e-02, ...,
#          5.30508347e+01,  2.51737475e+00,  3.31051216e+01],
#        ...,
#        [ 6.61490000e+04,  3.47480893e-01,  8.90194401e-02, ...,
#          4.85823784e+01, -2.99545288e-01,  4.15869904e+01],
#        [ 6.61490000e+04,  3.87527317e-01,  8.48154277e-02, ...,
#          2.48436127e+01,  6.75824106e-01,  1.27877502e+01],
#        [ 6.61490000e+04,  3.69292945e-01,  8.67586955e-02, ...,
#          3.94859009e+01, -3.41253424e+00,  3.17274895e+01]])

# %%
S = np.cov(X.T)
S
# Out:
# array([[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [ 0.00000000e+00,  8.18405418e-03, -3.86860064e-04, ...,
#         -1.17840595e+00,  9.20375238e-02, -1.52667330e+00],
#        [ 0.00000000e+00, -3.86860064e-04,  9.28644809e-05, ...,
#          1.11124613e-01, -8.77801532e-03,  1.28538409e-01],
#        ...,
#        [ 0.00000000e+00, -1.17840595e+00,  1.11124613e-01, ...,
#          1.72936851e+03,  2.76146282e+01,  1.27175604e+03],
#        [ 0.00000000e+00,  9.20375238e-02, -8.77801532e-03, ...,
#          2.76146282e+01,  2.75965646e+01,  2.41382544e+01],
#        [ 0.00000000e+00, -1.52667330e+00,  1.28538409e-01, ...,
#          1.27175604e+03,  2.41382544e+01,  2.15706481e+03]])

# %% [markdown]
# ### Definimos las funciones para calcular la matriz de covarianzas corregida, según la documentación del ejercicio

# %%
def cov_var_corregida(X):
  m = len(X)  
  X_centrada = X-X.mean(axis=0)
  return (1/(m-1))*X_centrada.T@X_centrada

# %% [markdown]
# ### Se calcula la matriz de covarianza corregida

# %%
S_corregida = cov_var_corregida(X)
S_corregida
# Out:
# array([[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [ 0.00000000e+00,  8.18405418e-03, -3.86860064e-04, ...,
#         -1.17840595e+00,  9.20375238e-02, -1.52667330e+00],
#        [ 0.00000000e+00, -3.86860064e-04,  9.28644809e-05, ...,
#          1.11124613e-01, -8.77801532e-03,  1.28538409e-01],
#        ...,
#        [ 0.00000000e+00, -1.17840595e+00,  1.11124613e-01, ...,
#          1.72936851e+03,  2.76146282e+01,  1.27175604e+03],
#        [ 0.00000000e+00,  9.20375238e-02, -8.77801532e-03, ...,
#          2.76146282e+01,  2.75965646e+01,  2.41382544e+01],
#        [ 0.00000000e+00, -1.52667330e+00,  1.28538409e-01, ...,
#          1.27175604e+03,  2.41382544e+01,  2.15706481e+03]])

# %% [markdown]
# ### Varianza total

# %%
# se calcula sumando la traza de la matriz de covarianza, en este caso usaremos la corregida.

T = np.trace(S_corregida)
T
# Out:
# 2417783677688.93

# %% [markdown]
# ### Varianza promedio

# %%
S2 = np.var(X)
S2
# Out:
# 89236067078.02802

# %% [markdown]
# ### Varianza Generalizada

# %%
# se calcula la varianza generalizada usando la matriz de covarianza corregida

VG = np.linalg.det(S_corregida)
VG
# Out:
# 0.0

# %% [markdown]
# ### Varianza Promedio

# %%
# se definen m,n 

m,n = X.shape
m,n

# se calcula la varianza promedio

VP = VG**(1/n)
VP
# Out:
# 0.0
